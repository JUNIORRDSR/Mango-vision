# %% [markdown]
# # 04 - Evaluacion
#
# Corre los scripts de evaluacion del clasificador y del detector, muestra las metricas y la matriz de confusion.

# %%
# !python src/evaluation/evaluate_cls.py

# %%
from IPython.display import Image
Image('reports/figures/confusion_matrix_cls.png')

# %%
import pandas as pd
pd.read_csv('reports/tables/metrics_cls.csv', index_col=0)

# %%
# Evaluacion del detector (ejecutar solo si el detector ya esta entrenado)
# !python src/evaluation/evaluate_det.py

# %%
# EigenCAM: ejemplos de atencion del clasificador
# !python src/evaluation/explain_cam.py --n 6
