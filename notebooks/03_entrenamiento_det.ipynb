# %% [markdown]
# # 03 - Entrenamiento del detector generico (Modelo 1)
#
# Requiere haber ejecutado previamente:
#
# ```
# python src/data_prep/download_roboflow.py
# python src/data_prep/collapse_detector_classes.py
# ```
#
# En Kaggle se recomienda guardar el dataset ya descargado y colapsado como Kaggle Dataset para no repetir la descarga en cada run.

# %%
# En Kaggle descomenta:
# !git clone https://github.com/<usuario>/Mango-vision.git
# %cd Mango-vision
# !pip install -q -r requirements.txt
# import os; os.environ['ROBOFLOW_API_KEY'] = '<api_key_aqui>'
# !python src/data_prep/download_roboflow.py
# !python src/data_prep/collapse_detector_classes.py

# %%
# !python src/training/train_det_generic.py --epochs 100 --batch 16 --imgsz 640
